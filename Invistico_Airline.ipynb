# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Invistico_Airline.csv")
df = df.head(40000)

# %%
df
# Out:
#       satisfaction  Gender      Customer Type  Age   Type of Travel     Class  \
# 0        satisfied  Female     Loyal Customer   65  Personal Travel       Eco
# 1        satisfied    Male     Loyal Customer   47  Personal Travel  Business
# 2        satisfied  Female     Loyal Customer   15  Personal Travel       Eco
# 3        satisfied  Female     Loyal Customer   60  Personal Travel       Eco
# 4        satisfied  Female     Loyal Customer   70  Personal Travel       Eco
# ...            ...     ...                ...  ...              ...       ...
# 39995    satisfied  Female  disloyal Customer   29  Business travel  Business
# 39996    satisfied    Male  disloyal Customer   29  Business travel  Business
# 39997    satisfied    Male  disloyal Customer   24  Business travel       Eco
# 39998    satisfied    Male  disloyal Customer   24  Business travel       Eco
# 39999    satisfied  Female  disloyal Customer   20  Business travel       Eco
#
# ...

# %%
df['satisfaction'].value_counts(normalize= True)*100
# Out:
# satisfaction
# dissatisfied    53.2175
# satisfied       46.7825
# Name: proportion, dtype: float64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    20013
# Male      19987
# Name: count, dtype: int64

# %%
df['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       39981
# disloyal Customer       19
# Name: count, dtype: int64

# %%
df['Customer Type'].value_counts(normalize=True)*100
# Out:
# Customer Type
# Loyal Customer       99.9525
# disloyal Customer     0.0475
# Name: proportion, dtype: float64

# %%
df['Type of Travel'].value_counts(normalize=True)*100
# Out:
# Type of Travel
# Personal Travel    99.9525
# Business travel     0.0475
# Name: proportion, dtype: float64

# %%
df['Class'].value_counts(normalize = True)*100
# Out:
# Class
# Eco         82.0575
# Eco Plus    11.2600
# Business     6.6825
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   satisfaction                       40000 non-null  object
#  1   Gender                             40000 non-null  object
#  2   Customer Type                      40000 non-null  object
#  3   Age                                40000 non-null  int64
#  4   Type of Travel                     40000 non-null  object
#  5   Class                              40000 non-null  object
#  6   Flight Distance                    40000 non-null  int64
#  7   Seat comfort                       40000 non-null  int64
#  8   Departure/Arrival time convenient  40000 non-null  int64
#  9   Food and drink                     40000 non-null  int64
#  10  Gate location                      40000 non-null  int64
# ...

# %%
df['Flight Distance'].mean()
# Out:
# np.float64(1791.4429)

# %%
df['Age'].mean()
# Out:
# np.float64(38.403675)

# %%
(df['Departure Delay in Minutes'].max())/60
# Out:
# 26.533333333333335

# %%
(df['Departure Delay in Minutes'].min())
# Out:
# 0

# %%
df.groupby('Gender')['satisfaction'].value_counts()
# Out:
# Gender  satisfaction
# Female  satisfied       16697
#         dissatisfied     3316
# Male    dissatisfied    17971
#         satisfied        2016
# Name: count, dtype: int64

# %%
df.groupby('Customer Type')['satisfaction'].value_counts()
# Out:
# Customer Type      satisfaction
# Loyal Customer     dissatisfied    21287
#                    satisfied       18694
# disloyal Customer  satisfied          19
# Name: count, dtype: int64

# %%
df.groupby('satisfaction')['Flight Distance'].mean()
# Out:
# satisfaction
# dissatisfied    1990.019730
# satisfied       1565.551542
# Name: Flight Distance, dtype: float64

# %%
df.groupby('satisfaction')['Age'].mean()
# Out:
# satisfaction
# dissatisfied    38.529196
# satisfied       38.260888
# Name: Age, dtype: float64

# %%
df.groupby('satisfaction')[['Departure Delay in Minutes','Arrival Delay in Minutes']].mean()
# Out:
#               Departure Delay in Minutes  Arrival Delay in Minutes
# satisfaction
# dissatisfied                   18.242965                 18.709454
# satisfied                       9.992786                 10.295085

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   satisfaction                       40000 non-null  object
#  1   Gender                             40000 non-null  object
#  2   Customer Type                      40000 non-null  object
#  3   Age                                40000 non-null  int64
#  4   Type of Travel                     40000 non-null  object
#  5   Class                              40000 non-null  object
#  6   Flight Distance                    40000 non-null  int64
#  7   Seat comfort                       40000 non-null  int64
#  8   Departure/Arrival time convenient  40000 non-null  int64
#  9   Food and drink                     40000 non-null  int64
#  10  Gate location                      40000 non-null  int64
# ...

# %%
df.groupby(['Gender','Class'])['satisfaction'].value_counts(normalize=True)*100
# Out:
# Gender  Class     satisfaction
# Female  Business  satisfied       82.250755
#                   dissatisfied    17.749245
#         Eco       satisfied       83.563898
#                   dissatisfied    16.436102
#         Eco Plus  satisfied       83.157895
#                   dissatisfied    16.842105
# Male    Business  dissatisfied    87.694589
#                   satisfied       12.305411
#         Eco       dissatisfied    89.929329
#                   satisfied       10.070671
#         Eco Plus  dissatisfied    91.142086
#                   satisfied        8.857914
# Name: proportion, dtype: float64

# %%
df.groupby('Type of Travel')['Departure Delay in Minutes'].mean().sort_values(ascending=False)
# Out:
# Type of Travel
# Personal Travel    14.384933
# Business travel    11.000000
# Name: Departure Delay in Minutes, dtype: float64

# %%
df.groupby('satisfaction')['Seat comfort'].mean()
# Out:
# satisfaction
# dissatisfied    2.584300
# satisfied       3.203548
# Name: Seat comfort, dtype: float64

# %%
df.groupby('Class')['Food and drink'].mean().sort_values(ascending = False)
# Out:
# Class
# Eco Plus    2.801732
# Business    2.785260
# Eco         2.781403
# Name: Food and drink, dtype: float64

# %%
service_features = [
    'Seat comfort',
    'Departure/Arrival time convenient',
    'Food and drink',
    'Gate location',
    'Inflight wifi service',
    'Inflight entertainment',
    'Online support',
    'Ease of Online booking',
    'On-board service',
    'Leg room service',
    'Baggage handling',
    'Checkin service',
    'Cleanliness',
    'Online boarding'
]
df[service_features].mean().sort_values(ascending = False)
# Out:
# Cleanliness                          3.806225
# Baggage handling                     3.779550
# On-board service                     3.534500
# Leg room service                     3.514325
# Checkin service                      3.449800
# Online support                       3.444900
# Departure/Arrival time convenient    3.425150
# Ease of Online booking               3.423375
# Online boarding                      3.335475
# Inflight entertainment               3.225850
# Inflight wifi service                3.211600
# Gate location                        2.963025
# Seat comfort                         2.874000
# Food and drink                       2.783950
# dtype: float64

# %%
df.groupby('satisfaction')['Inflight entertainment'].value_counts()
# Out:
# satisfaction  Inflight entertainment
# dissatisfied  3                         6116
#               2                         5488
#               4                         4371
#               1                         3459
#               5                         1135
#               0                          718
# satisfied     4                         7683
#               5                         7139
#               3                         1360
#               2                          910
#               0                          856
#               1                          765
# Name: count, dtype: int64

# %%
df.groupby('satisfaction')['Online boarding'].mean()
# Out:
# satisfaction
# dissatisfied    3.077183
# satisfied       3.629295
# Name: Online boarding, dtype: float64

# %%
service_features = [
    'Seat comfort',
    'Departure/Arrival time convenient',
    'Food and drink',
    'Gate location',
    'Inflight wifi service',
    'Inflight entertainment',
    'Online support',
    'Ease of Online booking',
    'On-board service',
    'Leg room service',
    'Baggage handling',
    'Checkin service',
    'Cleanliness',
    'Online boarding'
]

df[service_features].mean().sort_values(ascending = False)
# Out:
# Cleanliness                          3.806225
# Baggage handling                     3.779550
# On-board service                     3.534500
# Leg room service                     3.514325
# Checkin service                      3.449800
# Online support                       3.444900
# Departure/Arrival time convenient    3.425150
# Ease of Online booking               3.423375
# Online boarding                      3.335475
# Inflight entertainment               3.225850
# Inflight wifi service                3.211600
# Gate location                        2.963025
# Seat comfort                         2.874000
# Food and drink                       2.783950
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   satisfaction                       40000 non-null  object
#  1   Gender                             40000 non-null  object
#  2   Customer Type                      40000 non-null  object
#  3   Age                                40000 non-null  int64
#  4   Type of Travel                     40000 non-null  object
#  5   Class                              40000 non-null  object
#  6   Flight Distance                    40000 non-null  int64
#  7   Seat comfort                       40000 non-null  int64
#  8   Departure/Arrival time convenient  40000 non-null  int64
#  9   Food and drink                     40000 non-null  int64
#  10  Gate location                      40000 non-null  int64
# ...

# %%
df.groupby('satisfaction')['Departure Delay in Minutes'].mean()
# Out:
# satisfaction
# dissatisfied    18.242965
# satisfied        9.992786
# Name: Departure Delay in Minutes, dtype: float64

# %%
df["satisfaction_score"] = df["satisfaction"].map({
    "satisfied": 1,
    "dissatisfied": 0
})

# %%
avg_delay = (
    df.groupby("satisfaction")["Departure Delay in Minutes"]
    .mean()
    .round(2)
)

# %%
correlation = df['Departure Delay in Minutes'].corr(df['satisfaction_score'])
print(avg_delay)
print(correlation)
# Out:
# satisfaction
# dissatisfied    18.24
# satisfied        9.99
# Name: Departure Delay in Minutes, dtype: float64
# -0.10893140232098929

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   satisfaction                       40000 non-null  object
#  1   Gender                             40000 non-null  object
#  2   Customer Type                      40000 non-null  object
#  3   Age                                40000 non-null  int64
#  4   Type of Travel                     40000 non-null  object
#  5   Class                              40000 non-null  object
#  6   Flight Distance                    40000 non-null  int64
#  7   Seat comfort                       40000 non-null  int64
#  8   Departure/Arrival time convenient  40000 non-null  int64
#  9   Food and drink                     40000 non-null  int64
#  10  Gate location                      40000 non-null  int64
# ...

# %%
df.groupby('Type of Travel')['Arrival Delay in Minutes'].mean()
# Out:
# Type of Travel
# Business travel    14.315789
# Personal Travel    14.770496
# Name: Arrival Delay in Minutes, dtype: float64

# %%
(df['Arrival Delay in Minutes']>30).mean()*100
# Out:
# np.float64(13.900000000000002)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
satisfaction_by_class  = (df.groupby(['Class','satisfaction']).size().unstack())
satisfaction_by_class.plot(kind = 'bar')
plt.title("Satisfication count by class")
plt.xlabel("Class")
plt.ylabel("Numbers")
plt.xticks(rotation = 0)
plt.show()

# %%
satisfaction_by_class = (df.groupby(['Class','satisfaction']).size().unstack())
satisfaction_by_class.plot(kind = 'bar')
plt.title("satisication count by class")
plt.xlabel("Class")
plt.ylabel("Number of customers")
plt.xticks(rotation = 0)
plt.show()

# %%
plt.figure()
sns.countplot(x = 'Gender',data = df,palette='viridis')
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10616\1513228949.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Gender',data = df,palette='viridis')

# %%
satisfied_dist = df[df['satisfaction'] == 'satisfied']['Flight Distance']
dissatisfied_dist = df[df['satisfaction'] == 'dissatisfied']['Flight Distance']
plt.figure()
plt.boxplot([satisfied_dist,dissatisfied_dist],
           labels = ['satisfied','dissatisfied'])

Plt.title("Fight distance vs satifscation")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10616\1226761368.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([satisfied_dist,dissatisfied_dist],
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 7
#       3 plt.figure()
#       4 plt.boxplot([satisfied_dist,dissatisfied_dist],
#       5            labels = ['satisfied','dissatisfied'])
# ----> 7 Plt.title("Fight distance vs satifscation")
#       8 plt.show()
#
# NameError: name 'Plt' is not defined

# %%
plt.figure()
sns.histplot(x = 'Age', data = df, palette='viridis')
plt.xlabel("Age Dist")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10616\173412286.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x = 'Age', data = df, palette='viridis')

# %%
service_features = [
    'Seat comfort',
    'Departure/Arrival time convenient',
    'Food and drink',
    'Gate location',
    'Inflight wifi service',
    'Inflight entertainment',
    'Online support',
    'Ease of Online booking',
    'On-board service',
    'Leg room service',
    'Baggage handling',
    'Checkin service',
    'Cleanliness',
    'Online boarding']

avg_service_rating = df[service_features].mean().sort_values(ascending = False)
plt.figure()
avg_service_rating.plot(kind = 'bar')
plt.title("Avg service rating")
plt.xlabel("Service featire")
plt.ylabel("Average rating")
plt.xticks(rotation = 75)
plt.show()

# %%
service_features = [
    'Seat comfort',
    'Departure/Arrival time convenient',
    'Food and drink',
    'Gate location',
    'Inflight wifi service',
    'Inflight entertainment',
    'Online support',
    'Ease of Online booking',
    'On-board service',
    'Leg room service',
    'Baggage handling',
    'Checkin service',
    'Cleanliness',
    'Online boarding']

avg_service_ratings = df[service_features].mean().sort_values(ascending = False)
plt.figure()
avg_service_rating.plot(kind = 'bar')
plt.xlabel("Service Feature")
plt.title("Average service featire")
plt.ylabel("Avg rating")
plt.xticks(rotation = 75)
plt.show()

# %%
df[['Flight Distance']].sort_values(by = 'Flight Distance',ascending=False).head()
# Out:
#        Flight Distance
# 27712             6924
# 15497             6907
# 21586             6889
# 9071              6882
# 9613              6865

# %%
df['Flight Distance'].sort_values(ascending = False).head()
# Out:
# 27712    6924
# 15497    6907
# 21586    6889
# 9071     6882
# 9613     6865
# Name: Flight Distance, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   satisfaction                       40000 non-null  object
#  1   Gender                             40000 non-null  object
#  2   Customer Type                      40000 non-null  object
#  3   Age                                40000 non-null  int64
#  4   Type of Travel                     40000 non-null  object
#  5   Class                              40000 non-null  object
#  6   Flight Distance                    40000 non-null  int64
#  7   Seat comfort                       40000 non-null  int64
#  8   Departure/Arrival time convenient  40000 non-null  int64
#  9   Food and drink                     40000 non-null  int64
#  10  Gate location                      40000 non-null  int64
# ...

# %%
df[df['Arrival Delay in Minutes']>60]
# Out:
#       satisfaction  Gender      Customer Type  Age   Type of Travel     Class  \
# 1        satisfied    Male     Loyal Customer   47  Personal Travel  Business
# 41       satisfied  Female     Loyal Customer   17  Personal Travel       Eco
# 81       satisfied  Female     Loyal Customer   67  Personal Travel       Eco
# 126      satisfied  Female     Loyal Customer   65  Personal Travel       Eco
# 154      satisfied  Female     Loyal Customer   55  Personal Travel       Eco
# ...            ...     ...                ...  ...              ...       ...
# 39825    satisfied    Male     Loyal Customer   11  Personal Travel       Eco
# 39908    satisfied    Male     Loyal Customer   44  Personal Travel       Eco
# 39940    satisfied  Female     Loyal Customer   66  Personal Travel       Eco
# 39965    satisfied    Male     Loyal Customer   63  Personal Travel       Eco
# 39986    satisfied  Female  disloyal Customer   30  Business travel  Business
#
# ...

# %%
df[df['Arrival Delay in Minutes']>60]
# Out:
#       satisfaction  Gender      Customer Type  Age   Type of Travel     Class  \
# 1        satisfied    Male     Loyal Customer   47  Personal Travel  Business
# 41       satisfied  Female     Loyal Customer   17  Personal Travel       Eco
# 81       satisfied  Female     Loyal Customer   67  Personal Travel       Eco
# 126      satisfied  Female     Loyal Customer   65  Personal Travel       Eco
# 154      satisfied  Female     Loyal Customer   55  Personal Travel       Eco
# ...            ...     ...                ...  ...              ...       ...
# 39825    satisfied    Male     Loyal Customer   11  Personal Travel       Eco
# 39908    satisfied    Male     Loyal Customer   44  Personal Travel       Eco
# 39940    satisfied  Female     Loyal Customer   66  Personal Travel       Eco
# 39965    satisfied    Male     Loyal Customer   63  Personal Travel       Eco
# 39986    satisfied  Female  disloyal Customer   30  Business travel  Business
#
# ...

# %%
df['satisfaction'].value_counts()
# Out:
# satisfaction
# dissatisfied    21287
# satisfied       18713
# Name: count, dtype: int64

# %%
df[(df['Customer Type'] == 'Loyal Customer') & (df['satisfaction'] == 'satisfied')]
# Out:
#       satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0        satisfied  Female  Loyal Customer   65  Personal Travel       Eco
# 1        satisfied    Male  Loyal Customer   47  Personal Travel  Business
# 2        satisfied  Female  Loyal Customer   15  Personal Travel       Eco
# 3        satisfied  Female  Loyal Customer   60  Personal Travel       Eco
# 4        satisfied  Female  Loyal Customer   70  Personal Travel       Eco
# ...            ...     ...             ...  ...              ...       ...
# 39976    satisfied    Male  Loyal Customer   61  Personal Travel       Eco
# 39977    satisfied    Male  Loyal Customer   20  Personal Travel       Eco
# 39978    satisfied    Male  Loyal Customer   26  Personal Travel       Eco
# 39979    satisfied  Female  Loyal Customer   17  Personal Travel       Eco
# 39980    satisfied    Male  Loyal Customer   69  Personal Travel       Eco
#
# ...

# %%
df[(df['Customer Type'] == 'Loyal Customer') & (df['satisfaction'] == 'dissatisfied')]
# Out:
#        satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 795    dissatisfied    Male  Loyal Customer   48  Personal Travel  Eco Plus
# 799    dissatisfied    Male  Loyal Customer   30  Personal Travel       Eco
# 803    dissatisfied    Male  Loyal Customer   19  Personal Travel       Eco
# 804    dissatisfied    Male  Loyal Customer   13  Personal Travel       Eco
# 805    dissatisfied    Male  Loyal Customer   31  Personal Travel       Eco
# ...             ...     ...             ...  ...              ...       ...
# 38368  dissatisfied  Female  Loyal Customer   29  Personal Travel       Eco
# 38369  dissatisfied  Female  Loyal Customer   37  Personal Travel       Eco
# 38370  dissatisfied  Female  Loyal Customer   16  Personal Travel       Eco
# 38372  dissatisfied    Male  Loyal Customer   32  Personal Travel  Eco Plus
# 38373  dissatisfied  Female  Loyal Customer   16  Personal Travel       Eco
#
# ...

# %%
df = pd.read_csv("Invistico_Airline.csv")
df = df.head(40000)

# %%
df
# Out:
#       satisfaction  Gender      Customer Type  Age   Type of Travel     Class  \
# 0        satisfied  Female     Loyal Customer   65  Personal Travel       Eco
# 1        satisfied    Male     Loyal Customer   47  Personal Travel  Business
# 2        satisfied  Female     Loyal Customer   15  Personal Travel       Eco
# 3        satisfied  Female     Loyal Customer   60  Personal Travel       Eco
# 4        satisfied  Female     Loyal Customer   70  Personal Travel       Eco
# ...            ...     ...                ...  ...              ...       ...
# 39995    satisfied  Female  disloyal Customer   29  Business travel  Business
# 39996    satisfied    Male  disloyal Customer   29  Business travel  Business
# 39997    satisfied    Male  disloyal Customer   24  Business travel       Eco
# 39998    satisfied    Male  disloyal Customer   24  Business travel       Eco
# 39999    satisfied  Female  disloyal Customer   20  Business travel       Eco
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   satisfaction                       40000 non-null  object
#  1   Gender                             40000 non-null  object
#  2   Customer Type                      40000 non-null  object
#  3   Age                                40000 non-null  int64
#  4   Type of Travel                     40000 non-null  object
#  5   Class                              40000 non-null  object
#  6   Flight Distance                    40000 non-null  int64
#  7   Seat comfort                       40000 non-null  int64
#  8   Departure/Arrival time convenient  40000 non-null  int64
#  9   Food and drink                     40000 non-null  int64
#  10  Gate location                      40000 non-null  int64
# ...

# %%
df['satisfaction'].value_counts()
# Out:
# satisfaction
# dissatisfied    21287
# satisfied       18713
# Name: count, dtype: int64

# %%
df['satisfaction'].value_counts(normalize=True).sort_values(ascending = True).head(1)*100
# Out:
# satisfaction
# satisfied    46.7825
# Name: proportion, dtype: float64

# %%
df['Gender'].value_counts(normalize=True).sort_values(ascending = True).head(1)*100
# Out:
# Gender
# Male    49.9675
# Name: proportion, dtype: float64

# %%
df['Customer Type'].value_counts(normalize=True)*100
# Out:
# Customer Type
# Loyal Customer       99.9525
# disloyal Customer     0.0475
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   satisfaction                       40000 non-null  object
#  1   Gender                             40000 non-null  object
#  2   Customer Type                      40000 non-null  object
#  3   Age                                40000 non-null  int64
#  4   Type of Travel                     40000 non-null  object
#  5   Class                              40000 non-null  object
#  6   Flight Distance                    40000 non-null  int64
#  7   Seat comfort                       40000 non-null  int64
#  8   Departure/Arrival time convenient  40000 non-null  int64
#  9   Food and drink                     40000 non-null  int64
#  10  Gate location                      40000 non-null  int64
# ...

# %%
df['Type of Travel'].value_counts(normalize=True)*100
# Out:
# Type of Travel
# Personal Travel    99.9525
# Business travel     0.0475
# Name: proportion, dtype: float64

# %%
df['Class'].value_counts()
# Out:
# Class
# Eco         32823
# Eco Plus     4504
# Business     2673
# Name: count, dtype: int64

# %%
df['Age'].mean()
# Out:
# np.float64(38.403675)

# %%
print(df['Flight Distance'].mean())
# Out:
# 1791.4429

# %%
df['Departure Delay in Minutes'].max()
# Out:
# 1592

# %%
df['Departure Delay in Minutes'].min()
# Out:
# 0

# %%
df.groupby('Gender')['satisfaction'].value_counts()
# Out:
# Gender  satisfaction
# Female  satisfied       16697
#         dissatisfied     3316
# Male    dissatisfied    17971
#         satisfied        2016
# Name: count, dtype: int64

# %%
df.groupby('Customer Type')['satisfaction'].value_counts()
# Out:
# Customer Type      satisfaction
# Loyal Customer     dissatisfied    21287
#                    satisfied       18694
# disloyal Customer  satisfied          19
# Name: count, dtype: int64

# %%
df.groupby('Class')['satisfaction'].value_counts()
# Out:
# Class     satisfaction
# Business  dissatisfied     1418
#           satisfied        1255
# Eco       dissatisfied    17458
#           satisfied       15365
# Eco Plus  dissatisfied     2411
#           satisfied        2093
# Name: count, dtype: int64

# %%
df.groupby('Type of Travel')['satisfaction'].value_counts()
# Out:
# Type of Travel   satisfaction
# Business travel  satisfied          19
# Personal Travel  dissatisfied    21287
#                  satisfied       18694
# Name: count, dtype: int64

# %%
df.groupby('satisfaction')['Flight Distance'].mean()
# Out:
# satisfaction
# dissatisfied    1990.019730
# satisfied       1565.551542
# Name: Flight Distance, dtype: float64

# %%
df.groupby('satisfaction')['Age'].mean()
# Out:
# satisfaction
# dissatisfied    38.529196
# satisfied       38.260888
# Name: Age, dtype: float64

# %%
df.groupby('satisfaction')[['Departure Delay in Minutes','Arrival Delay in Minutes']].mean()
# Out:
#               Departure Delay in Minutes  Arrival Delay in Minutes
# satisfaction
# dissatisfied                   18.242965                 18.709454
# satisfied                       9.992786                 10.295085

# %%
df.groupby(['Gender','Class'])['satisfaction'].value_counts(normalize=True)*100
# Out:
# Gender  Class     satisfaction
# Female  Business  satisfied       82.250755
#                   dissatisfied    17.749245
#         Eco       satisfied       83.563898
#                   dissatisfied    16.436102
#         Eco Plus  satisfied       83.157895
#                   dissatisfied    16.842105
# Male    Business  dissatisfied    87.694589
#                   satisfied       12.305411
#         Eco       dissatisfied    89.929329
#                   satisfied       10.070671
#         Eco Plus  dissatisfied    91.142086
#                   satisfied        8.857914
# Name: proportion, dtype: float64

# %%
df.groupby('Type of Travel')['Departure Delay in Minutes'].mean()
# Out:
# Type of Travel
# Business travel    11.000000
# Personal Travel    14.384933
# Name: Departure Delay in Minutes, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   satisfaction                       40000 non-null  object
#  1   Gender                             40000 non-null  object
#  2   Customer Type                      40000 non-null  object
#  3   Age                                40000 non-null  int64
#  4   Type of Travel                     40000 non-null  object
#  5   Class                              40000 non-null  object
#  6   Flight Distance                    40000 non-null  int64
#  7   Seat comfort                       40000 non-null  int64
#  8   Departure/Arrival time convenient  40000 non-null  int64
#  9   Food and drink                     40000 non-null  int64
#  10  Gate location                      40000 non-null  int64
# ...

# %%
df.groupby('satisfaction')['Seat comfort'].mean()
# Out:
# satisfaction
# dissatisfied    2.584300
# satisfied       3.203548
# Name: Seat comfort, dtype: float64

# %%
df.groupby('Class')['Food and drink'].mean()
# Out:
# Class
# Business    2.785260
# Eco         2.781403
# Eco Plus    2.801732
# Name: Food and drink, dtype: float64

# %%
service_features = [
    'Seat comfort',
    'Departure/Arrival time convenient',
    'Food and drink',
    'Gate location',
    'Inflight wifi service',
    'Inflight entertainment',
    'Online support',
    'Ease of Online booking',
    'On-board service',
    'Leg room service',
    'Baggage handling',
    'Checkin service',
    'Cleanliness',
    'Online boarding'
]

(df[service_features].mean().sort_values(ascending = False)).head(1)
# Out:
# Cleanliness    3.806225
# dtype: float64

# %%
service_features = [
    'Seat comfort',
    'Departure/Arrival time convenient',
    'Food and drink',
    'Gate location',
    'Inflight wifi service',
    'Inflight entertainment',
    'Online support',
    'Ease of Online booking',
    'On-board service',
    'Leg room service',
    'Baggage handling',
    'Checkin service',
    'Cleanliness',
    'Online boarding'
]

(df[service_features].mean().sort_values(ascending = False))
# Out:
# Cleanliness                          3.806225
# Baggage handling                     3.779550
# On-board service                     3.534500
# Leg room service                     3.514325
# Checkin service                      3.449800
# Online support                       3.444900
# Departure/Arrival time convenient    3.425150
# Ease of Online booking               3.423375
# Online boarding                      3.335475
# Inflight entertainment               3.225850
# Inflight wifi service                3.211600
# Gate location                        2.963025
# Seat comfort                         2.874000
# Food and drink                       2.783950
# dtype: float64

# %%
df
# Out:
#       satisfaction  Gender      Customer Type  Age   Type of Travel     Class  \
# 0        satisfied  Female     Loyal Customer   65  Personal Travel       Eco
# 1        satisfied    Male     Loyal Customer   47  Personal Travel  Business
# 2        satisfied  Female     Loyal Customer   15  Personal Travel       Eco
# 3        satisfied  Female     Loyal Customer   60  Personal Travel       Eco
# 4        satisfied  Female     Loyal Customer   70  Personal Travel       Eco
# ...            ...     ...                ...  ...              ...       ...
# 39995    satisfied  Female  disloyal Customer   29  Business travel  Business
# 39996    satisfied    Male  disloyal Customer   29  Business travel  Business
# 39997    satisfied    Male  disloyal Customer   24  Business travel       Eco
# 39998    satisfied    Male  disloyal Customer   24  Business travel       Eco
# 39999    satisfied  Female  disloyal Customer   20  Business travel       Eco
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   satisfaction                       40000 non-null  object
#  1   Gender                             40000 non-null  object
#  2   Customer Type                      40000 non-null  object
#  3   Age                                40000 non-null  int64
#  4   Type of Travel                     40000 non-null  object
#  5   Class                              40000 non-null  object
#  6   Flight Distance                    40000 non-null  int64
#  7   Seat comfort                       40000 non-null  int64
#  8   Departure/Arrival time convenient  40000 non-null  int64
#  9   Food and drink                     40000 non-null  int64
#  10  Gate location                      40000 non-null  int64
# ...

# %%
df = pd.read_csv("Invistico_Airline.csv")
df
# Out:
#         satisfaction  Gender      Customer Type  Age   Type of Travel  \
# 0          satisfied  Female     Loyal Customer   65  Personal Travel
# 1          satisfied    Male     Loyal Customer   47  Personal Travel
# 2          satisfied  Female     Loyal Customer   15  Personal Travel
# 3          satisfied  Female     Loyal Customer   60  Personal Travel
# 4          satisfied  Female     Loyal Customer   70  Personal Travel
# ...              ...     ...                ...  ...              ...
# 129875     satisfied  Female  disloyal Customer   29  Personal Travel
# 129876  dissatisfied    Male  disloyal Customer   63  Personal Travel
# 129877  dissatisfied    Male  disloyal Customer   69  Personal Travel
# 129878  dissatisfied    Male  disloyal Customer   66  Personal Travel
# 129879  dissatisfied  Female  disloyal Customer   38  Personal Travel
#
#            Class  Flight Distance  Seat comfort  \
# 0            Eco              265             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  int64
#  7   Seat comfort                       129880 non-null  int64
#  8   Departure/Arrival time convenient  129880 non-null  int64
#  9   Food and drink                     129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
# ...

# %%
df['satisfaction'].value_counts(normalize=True)
# Out:
# satisfaction
# satisfied       0.547328
# dissatisfied    0.452672
# Name: proportion, dtype: float64

# %%
df['satisfaction'].replace({'satisfied':1,'dissatisfied':0},inplace = True)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    65899
# Male      63981
# Name: count, dtype: int64

# %%
df['Gender'].replace({'Female':0,'Male':1},inplace = True)

# %%
df['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       106100
# disloyal Customer     23780
# Name: count, dtype: int64

# %%
df['Customer Type'].replace({'Loyal Customer':0,'disloyal Customer':1},inplace = True)

# %%
df['Type of Travel'].value_counts()
# Out:
# Type of Travel
# Business travel    89693
# Personal Travel    40187
# Name: count, dtype: int64

# %%
df['Type of Travel'].replace({'Business travel':0,'Personal Travel':1},inplace = True)

# %%
df['Class'].value_counts()
# Out:
# Class
# Business    62160
# Eco         58309
# Eco Plus     9411
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  int64
#  1   Gender                             129880 non-null  int64
#  2   Customer Type                      129880 non-null  int64
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  int64
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  int64
#  7   Seat comfort                       129880 non-null  int64
#  8   Departure/Arrival time convenient  129880 non-null  int64
#  9   Food and drink                     129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
# ...

# %%
df = pd.get_dummies(df,dtype = int)
df
# Out:
#         satisfaction  Gender  Customer Type  Age  Type of Travel  \
# 0                  1       0              0   65               1
# 1                  1       1              0   47               1
# 2                  1       0              0   15               1
# 3                  1       0              0   60               1
# 4                  1       0              0   70               1
# ...              ...     ...            ...  ...             ...
# 129875             1       0              1   29               1
# 129876             0       1              1   63               1
# 129877             0       1              1   69               1
# 129878             0       1              1   66               1
# 129879             0       0              1   38               1
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0                   265             0                                  0
# ...

# %%
plt.figure()
sns.boxplot(x = 'Age',data = df, palette='viridis')
plt.xlabel('Age')
plt.ylabel("Age")
plt.show()

# %%
plt.figure()
sns.boxplot(x = 'Flight Distance',data = df, palette='viridis')
plt.xlabel('distance')

plt.show()

# %%
df
# Out:
#         satisfaction  Gender  Customer Type  Age  Type of Travel  \
# 0                  1       0              0   65               1
# 1                  1       1              0   47               1
# 2                  1       0              0   15               1
# 3                  1       0              0   60               1
# 4                  1       0              0   70               1
# ...              ...     ...            ...  ...             ...
# 129875             1       0              1   29               1
# 129876             0       1              1   63               1
# 129877             0       1              1   69               1
# 129878             0       1              1   66               1
# 129879             0       0              1   38               1
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0                   265             0                                  0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
x = df.drop(['satisfaction'],axis = 1)
y = df['satisfaction']
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.2,stratify=y)

# %%
std_scaler = StandardScaler()
array1 = std_scaler.fit_transform(x)
df = pd.DataFrame(array1,columns=x.columns)

# %%
df.isna().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# Class_Business                         0
# Class_Eco                              0
# ...

# %%
df = df.fillna(df['Arrival Delay in Minutes'].mean())

# %%
x_train,x_test,y_train,y_test = train_test_split(df,y,random_state=42,test_size=0.2,stratify=y)

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_train = log_reg.predict(x_train)
con_matrix = confusion_matrix(y_train,y_pred_train)
print("The confusion matrix :\n",con_matrix)
acc_score = accuracy_score(y_train,y_pred_train)
print("The accuracy score :",acc_score)
clf_rpt = classification_report(y_train,y_pred_train)
print("The classification report :\n",clf_rpt)
# Out:
# The confusion matrix :
#  [[38435  8599]
#  [ 8488 48382]]
# The accuracy score : 0.8355501231906375
# The classification report :
#                precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82     47034
#            1       0.85      0.85      0.85     56870
#
#     accuracy                           0.84    103904
#    macro avg       0.83      0.83      0.83    103904
# weighted avg       0.84      0.84      0.84    103904

# %%
y_pred = log_reg.predict(x_test)
con_matrix = confusion_matrix(y_test,y_pred)
print("The confusion matrix :\n",con_matrix)
acc_score = accuracy_score(y_test,y_pred)
print("The accuracy score :",acc_score)
clf_rpt = classification_report(y_test,y_pred)
print("The classification report :\n",clf_rpt)
# Out:
# The confusion matrix :
#  [[ 9639  2120]
#  [ 2116 12101]]
# The accuracy score : 0.8369263935940868
# The classification report :
#                precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82     11759
#            1       0.85      0.85      0.85     14217
#
#     accuracy                           0.84     25976
#    macro avg       0.84      0.84      0.84     25976
# weighted avg       0.84      0.84      0.84     25976

# %%
knn_clf = KNeighborsClassifier()
knn_clf.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_train = knn_clf.predict(x_train)
con_matrix = confusion_matrix(y_train,y_pred_train)
print("The confusion matrix :\n",con_matrix)
acc_score = accuracy_score(y_train,y_pred_train)
print("The accuracy score :",acc_score)
clf_rpt = classification_report(y_train,y_pred_train)
print("The classification report :\n",clf_rpt)
# Out:
# The confusion matrix :
#  [[45116  1918]
#  [ 3659 53211]]
# The accuracy score : 0.9463254542654759
# The classification report :
#                precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     47034
#            1       0.97      0.94      0.95     56870
#
#     accuracy                           0.95    103904
#    macro avg       0.95      0.95      0.95    103904
# weighted avg       0.95      0.95      0.95    103904

# %%
y_pred = knn_clf.predict(x_test)
con_matrix = confusion_matrix(y_test,y_pred)
print("The confusion matrix :\n",con_matrix)
acc_score = accuracy_score(y_test,y_pred)
print("The accuracy score :",acc_score)
clf_rpt = classification_report(y_test,y_pred)
print("The classification report :\n",clf_rpt)
# Out:
# The confusion matrix :
#  [[11031   728]
#  [ 1260 12957]]
# The accuracy score : 0.9234678164459501
# The classification report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92     11759
#            1       0.95      0.91      0.93     14217
#
#     accuracy                           0.92     25976
#    macro avg       0.92      0.92      0.92     25976
# weighted avg       0.92      0.92      0.92     25976

# %%
dt_clf = DecisionTreeClassifier(random_state=42)
dt_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_train = dt_clf.predict(x_train)
con_matrix = confusion_matrix(y_train,y_pred_train)
print("The confusion matrix :\n",con_matrix)
acc_score = accuracy_score(y_train,y_pred_train)
print("The accuracy score :",acc_score)
clf_rpt = classification_report(y_train,y_pred_train)
print("The classification report :\n",clf_rpt)
# Out:
# The confusion matrix :
#  [[47034     0]
#  [    0 56870]]
# The accuracy score : 1.0
# The classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     47034
#            1       1.00      1.00      1.00     56870
#
#     accuracy                           1.00    103904
#    macro avg       1.00      1.00      1.00    103904
# weighted avg       1.00      1.00      1.00    103904

# %%
y_pred = dt_clf.predict(x_test)
con_matrix = confusion_matrix(y_test,y_pred)
print("The confusion matrix :\n",con_matrix)
acc_score = accuracy_score(y_test,y_pred)
print("The accuracy score :",acc_score)
clf_rpt = classification_report(y_test,y_pred)
print("The classification report :\n",clf_rpt)
# Out:
# The confusion matrix :
#  [[10934   825]
#  [  734 13483]]
# The accuracy score : 0.9399830612873422
# The classification report :
#                precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93     11759
#            1       0.94      0.95      0.95     14217
#
#     accuracy                           0.94     25976
#    macro avg       0.94      0.94      0.94     25976
# weighted avg       0.94      0.94      0.94     25976

# %%
model  = DecisionTreeClassifier(random_state = 42)
hyp_param = {'criterion':['gini','entropy'],
             'max_depth': [0,2,5,10],
             'min_samples_split':[5,10,15],
             'min_samples_leaf':[2,4,5,8,10]}

gscv_dt_model = GridSearchCV(model,param_grid=hyp_param,cv = 3,n_jobs=-1)
gscv_dt_model.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 2, 5, 10],
#                          'min_samples_leaf': [2, 4, 5, 8, 10],
#                          'min_samples_split': [5, 10, 15]})

# %%
dt_model = gscv_dt_model.best_estimator_
dt_model.fit(x_train,y_train)
y_pred_train = dt_model.predict(x_train)
con_matrix = confusion_matrix(y_train,y_pred_train)
print("The confusion matrix :\n",con_matrix)
acc_score = accuracy_score(y_train,y_pred_train)
print("The accuracy score :",acc_score)
clf_rpt = classification_report(y_train,y_pred_train)
print("The classification report :\n",clf_rpt)
# Out:
# The confusion matrix :
#  [[43741  3293]
#  [ 2900 53970]]
# The accuracy score : 0.9403969048352325
# The classification report :
#                precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93     47034
#            1       0.94      0.95      0.95     56870
#
#     accuracy                           0.94    103904
#    macro avg       0.94      0.94      0.94    103904
# weighted avg       0.94      0.94      0.94    103904

# %%
y_pred = dt_model.predict(x_test)
con_matrix = confusion_matrix(y_test,y_pred)
print("The confusion matrix :\n",con_matrix)
acc_score = accuracy_score(y_test,y_pred)
print("The accuracy score :",acc_score)
clf_rpt = classification_report(y_test,y_pred)
print("The classification report :\n",clf_rpt)
# Out:
# The confusion matrix :
#  [[10898   861]
#  [  806 13411]]
# The accuracy score : 0.9358253772713274
# The classification report :
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93     11759
#            1       0.94      0.94      0.94     14217
#
#     accuracy                           0.94     25976
#    macro avg       0.94      0.94      0.94     25976
# weighted avg       0.94      0.94      0.94     25976

# %%
from xgboost import XGBClassifier

# %%
xgb_clf = XGBClassifier()
xgb_clf.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_train = xgb_clf.predict(x_train)
con_matrix = confusion_matrix(y_train,y_pred_train)
print("The confusion matrix :\n",con_matrix)
acc_score = accuracy_score(y_train,y_pred_train)
print("The accuracy score :",acc_score)
clf_rpt = classification_report(y_train,y_pred_train)
print("The classification report :\n",clf_rpt)
# Out:
# The confusion matrix :
#  [[45845  1189]
#  [ 1882 54988]]
# The accuracy score : 0.9704438712657838
# The classification report :
#                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     47034
#            1       0.98      0.97      0.97     56870
#
#     accuracy                           0.97    103904
#    macro avg       0.97      0.97      0.97    103904
# weighted avg       0.97      0.97      0.97    103904

# %%
y_pred = xgb_clf.predict(x_test)
con_matrix = confusion_matrix(y_test,y_pred)
print("The confusion matrix :\n",con_matrix)
acc_score = accuracy_score(y_test,y_pred)
print("The accuracy score :",acc_score)
clf_rpt = classification_report(y_test,y_pred)
print("The classification report :\n",clf_rpt)
# Out:
# The confusion matrix :
#  [[11313   446]
#  [  606 13611]]
# The accuracy score : 0.9595010779180783
# The classification report :
#                precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     11759
#            1       0.97      0.96      0.96     14217
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
import pickle

# %%
with open("xgb_cassifer.pkl",'wb') as file:
    pickle.dump(xgb_clf,file)
